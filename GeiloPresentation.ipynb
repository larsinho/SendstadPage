# %% [markdown]
# # Real Options and Regime Switching
#
# ## By Lars Sendstad

# %%
# jupyter nbconvert GeiloPresentation.ipynb --to slides --reveal-prefix=reveal.js
# code to rerender slides

# %% [markdown]
# ## My start
#
# - We show a lot of stuff
# - Here it goes $\Phi^{\ell}$

# %%
# cell 1
from bokeh.plotting import figure, show, output_notebook, output_file, reset_output
p = figure(width=300, height=300)
p.line(range(5), range(5))
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49980eca-ee11-4061-bcd8-77686c943dcf">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="c5dccd13-e88d-4af1-836c-8a0dabcbe09b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c5dccd13-e88d-4af1-836c-8a0dabcbe09b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c5dccd13-e88d-4af1-836c-8a0dabcbe09b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c5dccd13-e88d-4af1-836c-8a0dabcbe09b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"411b6945-0be3-474d-a08e-4264f3cb765d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4],"y":[0,1,2,3,4]}},"id":"34c5513a-d0ad-4d56-8580-215e6db85c0a","type":"ColumnDataSource"},{"attributes":{},"id":"f1f81a92-cf16-4b23-ba44-40ca4b50ee09","type":"BasicTicker"},{"attributes":{"below":[{"id":"4a2c517e-3386-4580-addf-3f3d77ac1fc3","type":"LinearAxis"}],"left":[{"id":"7f282ec7-a701-4f3e-8193-e8fe92047117","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"4a2c517e-3386-4580-addf-3f3d77ac1fc3","type":"LinearAxis"},{"id":"2e9e8cd9-c61d-4fb9-b71e-bd64b410638b","type":"Grid"},{"id":"7f282ec7-a701-4f3e-8193-e8fe92047117","type":"LinearAxis"},{"id":"14503089-ea85-4e28-87a1-b44721f20b59","type":"Grid"},{"id":"47a23623-cbd8-494e-9e0f-d49f5bc18022","type":"BoxAnnotation"},{"id":"305a4a66-de20-4aa1-849d-81fcce3de840","type":"GlyphRenderer"}],"title":{"id":"32dd076c-7ead-4d94-b513-002217e9f04b","type":"Title"},"tool_events":{"id":"2a3bc3cb-39d5-46b2-a9de-ee9fd4b9d122","type":"ToolEvents"},"toolbar":{"id":"4fdfa56e-c037-4399-9bcc-3b242e4adbc6","type":"Toolbar"},"x_range":{"id":"e839a620-a4a9-4910-9c03-01d2625addf1","type":"DataRange1d"},"y_range":{"id":"1f2c5a53-d411-40af-9084-f0ae8b034df6","type":"DataRange1d"}},"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad737e02-8f5c-4390-8dc1-741bb110468e","type":"Line"},{"attributes":{},"id":"cc363044-bdce-4ad5-a754-ba51749d12c7","type":"BasicTicker"},{"attributes":{"plot":{"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"}},"id":"432ef4b6-208d-4bcb-b17c-363a32d12ac5","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"},"ticker":{"id":"f1f81a92-cf16-4b23-ba44-40ca4b50ee09","type":"BasicTicker"}},"id":"14503089-ea85-4e28-87a1-b44721f20b59","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7185595c-dfb9-4d98-a3ae-297d71ce0657","type":"Line"},{"attributes":{"callback":null},"id":"e839a620-a4a9-4910-9c03-01d2625addf1","type":"DataRange1d"},{"attributes":{"plot":{"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc363044-bdce-4ad5-a754-ba51749d12c7","type":"BasicTicker"}},"id":"2e9e8cd9-c61d-4fb9-b71e-bd64b410638b","type":"Grid"},{"attributes":{},"id":"26aa7e59-303d-4524-8c5b-15915d1c117d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"}},"id":"d70260ad-22e1-4325-ba7e-ec918ae13beb","type":"ResetTool"},{"attributes":{"plot":{"id":"c6f62d67-dcd2-4719-8807-0cc3c1ba6adc","subtype":"Figure","type":"Plot"}},"id":"134eb564-7b41-4b7f-8f1b-704410eb6243","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"134eb564-7b41-4b7f-8f1b-704410eb6243","type":"PanTool"},{"id":"481ea1ec-3160-492e-8582-c21b1811cd3b","type":"WheelZoomTool"},{"id":"ab31a0c6-a502-4faa-ae31-6b76cc8a6e67","type":"BoxZoomTool"},{"id":"df4439aa-5518-4fb4-8121-f1bae890f2e7","type":"SaveTool"},{"id":"d70260ad-22e1-4325-ba7e-ec918ae13beb","type":"ResetTool"},{"id":"432ef4b6-208d-4bcb-b17c-363a32d12ac5","type":"HelpTool"}]},"id":"4fdfa56e-c037-4399-9bcc-3b242e4adbc6","type":"Toolbar"},{"attributes":{"data_source":{"id":"34c5513a-d0ad-4d56-8580-215e6db85c0a","type":"ColumnDataSource"},"glyph":{"id":"7185595c-dfb9-4d98-a3ae-297d71ce0657","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ad737e02-8f5c-4390-8dc1-741bb110468e","type":"Line"},"selection_glyph":null},"id":"305a4a66-de20-4aa1-849d-81fcce3de840","type":"GlyphRenderer"},{"attributes":{},"id":"1edc793b-0643-4bfa-81d5-6468907a228d","type":"BasicTickFormatter"},{"attributes":{},"id":"2a3bc3cb- ...
